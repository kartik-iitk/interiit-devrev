# %% [markdown]
# # Clutering themes approach
#
# We'll try to cluster the themes, and then have QA models fine tuned for each of the clusters.

# %% [markdown]
# ## Loading dataset

# %%
import gdown

def download_test_data(round = 1):
    """Download the test data (4 csv files)"""
    assert round in [1,2], "round can be 1 or 2"
    ids = [
        [
            "15WPYOD3ZLShFq_NRtiBHbpz3RTvc8ZWR",
            "15yxIF27NvEa3l12yNy6F5h8lGCJ2n7rf",
            "1Ilpxyj_0T-1KzQMdVSEbSmc1ybxOv69G",
            "1nkEDQZJY6_cAEVw3JlaKCgz0C6mDSYiv"
        ],
        [
            "1-3fMldkBVsTAX3W5JewdAdlUG_agexG0",
            "1-59pQe8TH7UaORF1RSqzFWybMJShdf1U",
            "1-AbnJRRHQiTU5zyUdDC2gUwbIGkEF5l6",
            "1-Px6FFj043L7lbAEBOAMSy2bdoPiVNhy"
        ]
    ]
    for id in ids[round-1]:
        url = f"https://drive.google.com/u/1/uc?id={id}&export=download"
        gdown.download(url, quiet=True)

# %%
download_test_data(round=2)

# %%
import pandas as pd
paragraphs2 = pd.read_csv('input_paragraph.csv')
print(type(paragraphs2))
paragraphs2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    id                                          paragraph    theme
# 0   1  In The New Yorker music critic Jody Rosen desc...  Beyoncé
# 1   2  Beyoncé's second solo album B'Day was released...  Beyoncé
# 2   3  In July 2002, Beyoncé continued her acting car...  Beyoncé
# 3   4  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  Beyoncé
# 4   5  Forbes magazine began reporting on Beyoncé's e...  Beyoncé

# %%
uniq_theme_list2 = list(paragraphs2['theme'].unique())
para_list2 = list(paragraphs2['paragraph'])

print(f"We have {len(para_list2)} pargraphs in total & those belong to {len(uniq_theme_list2)} unique themes")
# Out:
# We have 13481 pargraphs in total & those belong to 361 unique themes

# %% [markdown]
# Concatenate the paragraphs of a theme as we would like to cluster themes and not paragraphs

# %%
para_list2 = [' '.join(paragraphs2[paragraphs2['theme']==theme]['paragraph']) for theme in uniq_theme_list2]

# %% [markdown]
# ## Main Pipeline

# %% [markdown]
# ### Setting up helper functions

# %%
def generate_embeddings(embedding_model, para_list):
  print("Generating the document embeddings...")
  para_embeddings = embedding_model(para_list)
  para_embeddings = para_embeddings.numpy()
  return para_embeddings

def fit_bertopic_model(topic_model, para_list, para_embeddings):
  print("Fitting the model using the paras & their embeddings")
  # print(type(para_embeddings))
  # np_para_emb = para_embeddings.numpy() # Converting the para_embeddings from EagerTensor -> numpy array
  topic_model.fit(documents = para_list, embeddings = para_embeddings) # Can use pre-trained embeddings directly

def perform_cluster_prediction(topic_model, para_list, para_embeddings):
  np_para_emb = para_embeddings #.numpy() # Converting the para_embeddings from EagerTensor -> numpy array
  try:
    topics, scores = topic_model.transform(para_list, np_para_emb) # Predicting the documents clusters
  except:
    topics
  return topics, scores

def get_max_cluster_id(theme_cluster_count_dict):
  """
  Input: theme_cluster_count_dict : A dictionary with cluster_id as keys and their # of occurences as the value
  """
  max_count = 0
  cid = -1
  for key in theme_cluster_count_dict:
    if (theme_cluster_count_dict[key] > max_count):
      max_count = theme_cluster_count_dict[key]
      cid = key
  return cid

def get_cid_to_list_topics(mydic):
  """
  Input: mydic: Dict mapping theme --> cluster id
  Returns a dict with cluster id as key and the value is a list of themes associated to it.
  """
  cluster_id_to_topic = {}
  for topic, cluster_id in mydic.items():
      if cluster_id not in cluster_id_to_topic:
          cluster_id_to_topic[cluster_id] = [topic]
      else:
          cluster_id_to_topic[cluster_id].append(topic)
  return cluster_id_to_topic

def get_avg_themes_per_cluster(topic_model):
  data = topic_model.get_topic_info()
  avg = data[data['Topic']!=-1]['Count'].mean()
  return avg

def generate_theme_to_cluster_mapping(paragraphs, topics):
  global_idx = 0

  theme_to_cluster_mapping = {} # This will hold the final theme to cluster mapping

  uniq_theme_list_df = paragraphs['theme'].unique()

  for theme in uniq_theme_list_df:

    theme_df = paragraphs[paragraphs['theme']==theme] # Getting the part of df with the curr theme
    theme_cluster_count_dict = {} # To store the count of each cluster_id the prev theme was mapped to. '-1' cluster_id indicates that we'll be using the global model.

    for i in range(len(theme_df)):
        curr_cid = topics[global_idx]
        if theme_cluster_count_dict.get(curr_cid)==None:
          theme_cluster_count_dict[curr_cid] = 0
        theme_cluster_count_dict[curr_cid] += 1 # Incrementing the count
    global_idx+=1
    mode_cid = get_max_cluster_id(theme_cluster_count_dict)
    theme_to_cluster_mapping[theme] = mode_cid

  return theme_to_cluster_mapping

# %% [markdown]
# ### Installing and importing some libraries

# %%
# %%capture
# !pip install bertopic

# %%
from bertopic import BERTopic
import tensorflow_hub
from umap import UMAP
import copy
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import Birch

# %% [markdown]
# ### Generate Paragraph Embeddings

# %%
# Generating Embeddings Once
embedding_model = tensorflow_hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")
para_embeddings2 = generate_embeddings(embedding_model, para_list2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-51c9f90a8332> in <module>
#       1 # Generating Embeddings Once
#       2 embedding_model = tensorflow_hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")
# ----> 3 para_embeddings2 = generate_embeddings(embedding_model, para_list2)
#
# NameError: name 'para_list2' is not defined

# %% [markdown]
# ### Initialize BERTopic Model

# %%
vectorizer_model = CountVectorizer(stop_words="english")
brc_model = Birch(branching_factor=50, n_clusters=None, threshold=0.4)
umap_model = UMAP(n_neighbors=15, n_components=6, min_dist=0.0, metric='cosine')


topic_model = BERTopic(
                  low_memory = True,
                  umap_model = umap_model,
                  hdbscan_model = brc_model,
                  embedding_model = embedding_model,
                  vectorizer_model = vectorizer_model, 
                  calculate_probabilities = True, 
                  verbose = True, 
                  nr_topics = int(0.3*len(uniq_theme_list2))
                )

# %% [markdown]
# ## Running the Model

# %%
fit_bertopic_model(topic_model, para_list2, para_embeddings2)
topics, scores = perform_cluster_prediction(topic_model, para_list2, para_embeddings2)
theme_to_cluster_mapping = generate_theme_to_cluster_mapping(paragraphs2, topics)
cid_to_themes_mapping = (get_cid_to_list_topics(theme_to_cluster_mapping))
avg_themes_per_cluster = get_avg_themes_per_cluster(topic_model)
topic_info = topic_model.get_topic_info()
unclustered = topic_info[topic_info['Topic']==-1]['Count']
if unclustered.empty:
  unclustered = 0
  num_clusters = len(topic_info['Topic'])
else:
  unclustered = int(unclustered)
  num_clusters = len(topic_info['Topic'])-1
print('--------------------------------------------------------------------------------------------------------------------------------------------')
print(f"Main Dataset Results:")
print(f"#Themes unclustered = {unclustered}\nAvg. #Themes / cluster = {avg_themes_per_cluster}\n# clusters = {num_clusters}")
# Out:
# Fitting the model using the paras & their embeddings
# 2023-02-03 16:58:53,892 - BERTopic - Reduced dimensionality
# 2023-02-03 16:58:53,915 - BERTopic - Clustered reduced embeddings
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/bertopic/backend/_use.py:54: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity instead.
# 2023-02-03 16:58:57,603 - BERTopic - Reduced number of topics from 37 to 37
# 2023-02-03 16:58:59,541 - BERTopic - Reduced dimensionality
# 2023-02-03 16:58:59,544 - BERTopic - Predicted clusters
# --------------------------------------------------------------------------------------------------------------------------------------------
# Main Dataset Results:
# #Themes unclustered = 0
# Avg. #Themes / cluster = 9.756756756756756
# # clusters = 37

# %%
# topic_model.save('birch_dot4_thresh', save_embedding_model=False)

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                         Name
# 0       0     11                   0_film_music_album_madonna
# 1       1      4        1_architecture_cubism_riba_architects
# 2       2      8                   2_nasser_tito_torch_soviet
# 3       3     23                    3_data_windows_dell_audio
# 4       4     26                         4_city_new_york_area
# 5       5      9             5_law_court_constitution_supreme
# 6       6     15                6_uranium_light_copper_energy
# 7       7     14           7_philosophy_quran_hayek_whitehead
# 8       8     21              8_species_bacteria_birds_plants
# 9       9      5  9_education_universities_university_schools
# 10     10     17              10_children_somali_africa_child
# 11     11     10                11_greek_roman_ottoman_empire
# 12     12     15           12_language_languages_dutch_slavic
# 13     13     15                     13_air_aircraft_war_army
# 14     14      9              14_jews_jewish_apollo_ashkenazi
# 15     15      8               15_university_school_bell_yale
# 16     16     11              16_island_islands_alaska_tuvalu
# 17     17     11                 17_copyright_cbc_youtube_ibm
# 18     18      7              18_church_presbyterian_pope_god
# 19     19      2                   19_dst_time_clock_daylight
# 20     20     12                 20_league_football_club_team
# 21     21     14                21_city_paris_mexico_portugal
# 22     22      8           22_cotton_ice_antarctica_antarctic
# 23     23     11                  23_sexual_pain_brain_memory
# 24     24     11           24_india_delhi_kathmandu_hyderabad
# 25     25      7                 25_race_black_racial_african
# 26     26     14               26_french_napoleon_german_john
# 27     27      2              27_financial_crisis_drug_credit
# 28     28      1           28_israel_israeli_jewish_jerusalem
# 29     29      5               29_mosaic_mosaics_gothic_abbey
# 30     30      7                 30_ming_qing_samurai_emperor
# 31     31      7         31_party_kerry_schwarzenegger_leader
# 32     32      4         32_chopin_mandolin_music_instruments
# 33     33      7              33_energy_vacuum_neumann_matter
# 34     34      2                      34_red_green_color_blue
# 35     35      3           35_tennessee_florida_state_spanish
# 36     36      5              36_iran_cyprus_armenian_turkish

# %% [markdown]
# ### Visualizing the clustered paragraphs

# %%
train_data_map = cid_to_themes_mapping

# %%
topic_model.visualize_barchart(top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ffc59df4-feb4-4844-9114-935400e5623d" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffc59df4-feb4-4844-9114-935400e5623d")) {                    Plotly.newPlot(                        "ffc59df4-feb4-4844-9114-935400e5623d",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01587784286855982,0.016553907654375918,0.01767863196538934,0.018098973724743075,0.019855908477970738],"y":["software  ","audio  ","dell  ","windows  ","data  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.014615237751026872,0.015926198042576688,0.016792663703443764,0.020939820755644233,0.04941563595111726],"y":["street  ","area  ","york  ","new  ","city  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.024327427898617277,0.024922925684270677,0.026436458504038335,0.028929320998602494,0.029216100631694577],"y":["glass  ","energy  ","copper  ","light  ","uranium  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.015941687738934365,0.01901018365863095,0.020198151752281315,0.02126935285097234,0.021524510774678682],"y":["buddhism  ","whitehead  ","hayek  ","quran  ","philosophy  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.01738356481614298,0.01986351017320485,0.020822750095305643,0.021255201510050597,0.034147844305150235],"y":["genes  ","plants  ","birds  ","bacteria  ","species  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.017416833220354335,0.01754692901611906,0.01820853888812491,0.018700367074742447,0.01887229552964598],"y":["labour  ","child  ","africa  ","somali  ","children  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.026305329515877423,0.02866433812020624,0.030462655376464656,0.03444815487147029,0.04482816031062847],"y":["comics  ","slavic  ","dutch  ","languages  ","language  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.020256915487158435,0.021629413798532778,0.023368684158771465,0.02497245766696264,0.025254425161759374],"y":["forces  ","army  ","war  ","aircraft  ","air  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.012926518588986665,0.013058796363887197,0.01798034785370298,0.021308239002244975,0.027253096008468557],"y":["switzerland  ","portugal  ","mexico  ","paris  ","city  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.021432161294878495,0.022225747421729638,0.02337596790885827,0.025286398002877797,0.03167262486932832],"y":["burke  ","john  ","german  ","napoleon  ","french  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth": ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="dbf3e12d-3681-4af1-84a0-c79ccf8b3318" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbf3e12d-3681-4af1-84a0-c79ccf8b3318")) {                    Plotly.newPlot(                        "dbf3e12d-3681-4af1-84a0-c79ccf8b3318",                        [{"customdata":[[0,"film | music | album | madonna | beyonc\u00e9",11],[1,"architecture | cubism | riba | architects | cubist",4],[2,"nasser | tito | torch | soviet | relay",8],[3,"data | windows | dell | audio | software",23],[4,"city | new | york | area | street",26],[5,"law | court | constitution | supreme | assent",9],[6,"uranium | light | copper | energy | glass",15],[7,"philosophy | quran | hayek | whitehead | buddhism",14],[8,"species | bacteria | birds | plants | genes",21],[9,"education | universities | university | schools | islamic",5],[10,"children | somali | africa | child | labour",17],[11,"greek | roman | ottoman | empire | rome",10],[12,"language | languages | dutch | slavic | comics",15],[13,"air | aircraft | war | army | forces",15],[14,"jews | jewish | apollo | ashkenazi | jesus",9],[15,"university | school | bell | yale | college",8],[16,"island | islands | alaska | tuvalu | ireland",11],[17,"copyright | cbc | youtube | ibm | shell",11],[18,"church | presbyterian | pope | god | baptist",7],[19,"dst | time | clock | daylight | circadian",2],[20,"league | football | club | team | season",12],[21,"city | paris | mexico | portugal | switzerland",14],[22,"cotton | ice | antarctica | antarctic | glacier",8],[23,"sexual | pain | brain | memory | identity",11],[24,"india | delhi | kathmandu | hyderabad | indian",11],[25,"race | black | racial | african | indigenous",7],[26,"french | napoleon | german | john | burke",14],[27,"financial | crisis | drug | credit | drugs",2],[28,"israel | israeli | jewish | jerusalem | arab",1],[29,"mosaic | mosaics | gothic | abbey | palace",5],[30,"ming | qing | samurai | emperor | china",7],[31,"party | kerry | schwarzenegger | leader | minority",7],[32,"chopin | mandolin | music | instruments | cappella",4],[33,"energy | vacuum | neumann | matter | time",7],[34,"red | green | color | blue | colors",2],[35,"tennessee | florida | state | spanish | states",3],[36,"iran | cyprus | armenian | turkish | greece",5]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>Words: %{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[11,4,8,23,26,9,15,14,21,5,17,10,15,15,9,8,11,11,7,2,12,14,8,11,11,7,14,2,1,5,7,7,4,7,2,3,5],"sizemode":"area","sizeref":0.01625,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[2.623311996459961,-15.13973617553711,3.6969923973083496,14.762849807739258,4.8798089027404785,-6.917630195617676,19.382062911987305,20.120346069335938,20.057273864746094,20.26512908935547,3.8578853607177734,0.82871013879776,19.23396873474121,1.818115234375,0.6965831518173218,2.4034202098846436,4.633073329925537,15.036083221435547,-6.91701078414917,19.543012619018555,2.325516939163208,0.8581945896148682,5.0038251876831055,19.669294357299805,4.053791046142578,19.418840408325195,1.1838971376419067,15.21420955657959,10.299259185791016,-14.89062213897705,1.0214344263076782,2.55844783782959,2.633898973464966,19.50977897644043,-14.820124626159668,4.662388324737549,10.254990577697754],"xaxis":"x","y":[7.352046966552734,-6.459046840667725,8.681985855102539,21.72537612915039,9.581046104431152,0.19005772471427917,-3.346926212310791,-2.5778961181640625,-2.924075126647949,-2.4442923069000244,8.81177806854248,5.387206077575684,-1.8797484636306763,6.350991249084473,5.228074550628662,6.585170745849609,9.294781684875488,21.998868942260742,0.19030277431 ...

# %%
hierarchical_topics = topic_model.hierarchical_topics(para_list2)
tree = topic_model.get_topic_tree(hierarchical_topics)
print(tree)
# Out:
# 100%|██████████| 36/36 [00:00<00:00, 113.74it/s]
# .
# ├─city_war_new_state_states
# │    ├─greek_language_roman_empire_century
# │    │    ├─israel_jews_jewish_apollo_israeli
# │    │    │    ├─■──israel_israeli_jewish_jerusalem_arab ── Topic: 28
# │    │    │    └─■──jews_jewish_apollo_ashkenazi_jesus ── Topic: 14
# │    │    └─greek_language_empire_roman_ottoman
# │    │         ├─greek_empire_ottoman_greece_roman
# │    │         │    ├─■──iran_cyprus_armenian_turkish_greece ── Topic: 36
# │    │         │    └─■──greek_roman_ottoman_empire_rome ── Topic: 11
# │    │         └─■──language_languages_dutch_slavic_comics ── Topic: 12
# │    └─city_new_war_state_states
# │         ├─city_new_population_area_state
# │         │    ├─race_african_black_racial_americans
# │         │    │    ├─■──race_black_racial_african_indigenous ── Topic: 25
# │         │    │    └─■──tennessee_florida_state_spanish_states ── Topic: 35
# │         │    └─city_new_area_island_population
# │         │         ├─city_new_area_island_population
# │         │         │    ├─■──island_islands_alaska_tuvalu_ireland ── Topic: 16
# │         │         │    └─city_new_area_population_largest
# │         │         │         ├─■──city_new_york_area_street ── Topic: 4
# │         │         │         └─■──city_paris_mexico_portugal_switzerland ── Topic: 21
# │         │         └─■──cotton_ice_antarctica_antarctic_glacier ── Topic: 22
# │         └─war_government_army_states_british
# │              ├─war_army_british_french_soviet
# │              │    ├─india_china_dynasty_ming_empire
# │              │    │    ├─■──india_delhi_kathmandu_hyderabad_indian ── Topic: 24
# │              │    │    └─■──ming_qing_samurai_emperor_china ── Topic: 30
# │              │    └─war_army_soviet_french_forces
# │              │         ├─war_army_french_german_forces
# │              │         │    ├─■──french_napoleon_german_john_burke ── Topic: 26
# │              │         │    └─■──air_aircraft_war_army_forces ── Topic: 13
# │              │         └─nasser_country_government_police_tito
# │              │              ├─■──nasser_tito_torch_soviet_relay ── Topic: 2
# │              │              └─■──children_somali_africa_child_labour ── Topic: 10
# │              └─law_church_party_kerry_court
# │                   ├─party_law_kerry_court_government
# │                   │    ├─■──party_kerry_schwarzenegger_leader_minority ── Topic: 31
# │                   │    └─■──law_court_constitution_supreme_assent ── Topic: 5
# │                   └─■──church_presbyterian_pope_god_baptist ── Topic: 18
# └─used_time_use_music_new
#      ├─music_season_new_game_league
#      │    ├─university_school_education_students_bell
#      │    │    ├─chopin_red_mandolin_music_architecture
#      │    │    │    ├─■──red_green_color_blue_colors ── Topic: 34
#      │    │    │    └─chopin_mandolin_music_architecture_mosaic
#      │    │    │         ├─architecture_mosaic_mosaics_gothic_cubism
#      │    │    │         │    ├─■──architecture_cubism_riba_architects_cubist ── Topic: 1
#      │    │    │         │    └─■──mosaic_mosaics_gothic_abbey_palace ── Topic: 29
#      │    │    │         └─■──chopin_mandolin_music_instruments_cappella ── Topic: 32
#      │    │    └─university_school_education_bell_students
#      │    │         ├─■──university_school_bell_yale_college ── Topic: 15
#      │    │         └─■──education_universities_university_schools_islamic ── Topic: 9
#      │    └─season_league_game_film_music
#      │         ├─season_league_film_music_album
#      │         │    ├─■──league_football_club_team_season ── Topic: 20
#      │         │    └─■──film_music_album_madonna_beyoncé ── Topic: 0
#      │         └─data_software_windows_video_dell
#      │              ├─■──data_windows_dell_audio_software ── Topic: 3
#      │              └─■──copyright_cbc_youtube_ibm_shell ── Topic: 17
#      └─energy_used_species_time_use
#           ├─species_sexual_human_pain_brain
#           │    ├─■──financial_crisis_drug_credit_drugs ── Topic: 27
#           │    └─species_sexual_human_pain_brain
#           │         ├─■──species_bacteria_birds_plants_genes ── Topic: 8
#           │         └─sexual_pain_brain_social_philosophy
#           │              ├─■──sexual_pain_brain_memory_identity ── Topic: 23
#           │              └─■──philosophy_quran_hayek_whitehead_buddhism ── Topic: 7
#           └─energy_light_uranium_used_copper
#                ├─energy_light_uranium_used_copper
#                │    ├─■──uranium_light_copper_energy_glass ── Topic: 6
#                │    └─■──energy_vacuum_neumann_matter_time ── Topic: 33
#                └─■──dst_time_clock_daylight_circadian ── Topic: 19

# %% [markdown]
# # Predicting on new themes

# %%
# Only for loading a saved model from a particular run, else ignore
old_model = BERTopic.load("cluster_model")

# %%
topic_info = old_model.get_topic_info()
topic_info
# Out:
#     Topic  Count                                          Name
# 0       0     38                 0_data_apple_software_windows
# 1       1     14                   1_chinese_china_dynasty_han
# 2       2     17                     2_air_aircraft_forces_war
# 3       3     16                      3_church_mary_pope_jesus
# 4       4     23             4_gaddafi_country_africa_children
# 5       5     19         5_theory_god_philosophy_enlightenment
# 6       6      9            6_london_southampton_beer_plymouth
# 7       7     18      7_language_languages_characters_dialects
# 8       8     24                   8_used_antenna_light_copper
# 9       9     20                    9_music_album_film_madonna
# 10     10      3                     10_dollar_times_coins_ecb
# 11     11     23                11_cells_species_bacteria_cell
# 12     12      6                          12_quran_al_ibn_text
# 13     13      8                   13_species_hunting_dogs_dog
# 14     14     13                   14_league_football_club_cup
# 15     15      6          15_alaska_mountains_montana_mountain
# 16     16      5            16_kerry_fbi_schwarzenegger_police
# 17     17      9                 17_burke_victoria_queen_lodge
# 18     18     12                     18_law_court_state_states
# 19     19     18                      19_city_paris_red_mexico
# 20     20     12              20_island_islands_bermuda_tuvalu
# 21     21     29                        21_city_new_state_area
# 22     22      8               22_energy_feynman_vacuum_matter
# 23     23     12             23_university_school_bell_college
# 24     24     10            24_ottoman_empire_armenian_armenia
# 25     25     20                 25_french_france_napoleon_war
# 26     26      9           26_neptune_ice_antarctica_antarctic
# 27     27      1    27_pharmacy_pharmacists_pharmacies_patient
# 28     28      8         28_architecture_mosaic_mosaics_cubism
# 29     29      6  29_schools_education_universities_university
# 30     30      1                    30_rhine_delta_river_flows
# 31     31      8                 31_nasser_soviet_tito_estonia
# 32     32      4             32_jews_jewish_ashkenazi_orthodox
# 33     33      5                  33_race_racial_black_african
# 34     34      2                       34_shell_ge_company_oil
# 35     35      8                35_sexual_pain_memory_identity
# 36     36      5                      36_dst_asthma_time_clock
# 37     37      6                        37_greek_rome_roman_bc
# 38     38      5                38_israel_iran_myanmar_israeli
# 39     39      3                  39_cotton_green_color_grapes
# 40     40      6           40_party_leader_parliament_minority
# 41     41      6            41_kathmandu_hyderabad_delhi_india
# 42     42      2        42_indigenous_peoples_neolithic_native

# %% [markdown]
# ## Preparing Test Data

# %%
# download_test_data(round=1)

# %%
import pandas as pd
paragraphs1 = pd.read_csv('paragraphs.csv')
print(type(paragraphs1))
paragraphs1.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-b28139b0a425> in <module>
#       1 import pandas as pd
# ----> 2 paragraphs1 = pd.read_csv('paragraphs.csv')
#       3 print(type(paragraphs1))
#       4 paragraphs1.head()
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'paragraphs.csv'

# %%
uniq_theme_list1 = list(paragraphs1['theme'].unique())
para_list1 = list(paragraphs1['paragraph'])

print(f"We have {len(para_list1)} pargraphs in total & those belong to {len(uniq_theme_list1)} unique themes")
# Out:
# We have 1179 pargraphs in total & those belong to 30 unique themes

# %% [markdown]
# ### Concatenate paragraphs

# %%
para_list1 = [' '.join(paragraphs1[paragraphs1['theme']==theme]['paragraph']) for theme in uniq_theme_list1]

# %% [markdown]
# ## Prediction Setup

# %% [markdown]
# ### Generate Embeddings

# %%
# embedding_model = tensorflow_hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %%
para_embeddings1 = generate_embeddings(embedding_model, para_list1)
# Out:
# Generating the document embeddings...

# %% [markdown]
# ### Make Predictions

# %%
preds,scores = old_model.transform(documents=para_list1,embeddings=para_embeddings1)

# %%
mapp = generate_theme_to_cluster_mapping(paragraphs1,preds)

# %%
cid_to_topic = get_cid_to_list_topics(mapp)

# %% [markdown]
# ### Cluster Assignment of New Topics

# %%
new_map = cid_to_topic

# %%
new_map
# Out:
# {0: ['IPod', 'Wayback_Machine', 'Web_browser', 'DevRev'],
#  1: ['2008_Sichuan_earthquake', 'Nanjing'],
#  2: ['Canadian_Armed_Forces'],
#  3: ['Cardinal_(Catholicism)', 'Heresy', 'Mary_(mother_of_Jesus)'],
#  4: ['Human_Development_Index'],
#  31: ['Warsaw_Pact'],
#  5: ['Materialism'],
#  6: ['Pub', 'Southampton'],
#  7: ['Catalan_language', 'Dialect'],
#  8: ['Paper'],
#  9: ['Adult_contemporary_music', 'Hard_rock'],
#  10: ['The_Times', 'United_States_dollar'],
#  11: ['Immunology'],
#  12: ['Imamah_(Shia_doctrine)'],
#  39: ['Grape'],
#  14: ['Everton_F.C.'],
#  15: ['Great_Plains'],
#  13: ['Biodiversity'],
#  16: ['Federal_Bureau_of_Investigation'],
#  34: ['Unknown']}

# %% [markdown]
# #### Displaying Cluster Assignments with the training map

# %%
for cluster in new_map:
  print(f"New Topics: {new_map[cluster]}")
  print(f"Assigned to: {train_data_map[cluster]}")
# Out:
# New Topics: ['IPod', 'Web_browser', 'Antenna_(radio)']
# Assigned to: ['The_Legend_of_Zelda:_Twilight_Princess', 'High-definition_television', 'Computer', 'MP3', 'Computer_security', 'Videoconferencing', 'Xbox_360', 'ASCII', 'Macintosh', 'Dell', 'Nintendo_Entertainment_System', 'Film_speed', 'Data_compression', 'Digimon', 'Gramophone_record', 'USB', 'PlayStation_3', 'LaserDisc', 'Software_testing', 'Compact_disc', 'Database', 'Windows_8', 'Super_Nintendo_Entertainment_System']
# New Topics: ['2008_Sichuan_earthquake', 'Muammar_Gaddafi', '1973_oil_crisis', 'Islamism']
# Assigned to: ['2008_Summer_Olympics_torch_relay', 'Russian_Soviet_Federative_Socialist_Republic', 'Josip_Broz_Tito', 'Myanmar', 'Dissolution_of_the_Soviet_Union', 'Gamal_Abdel_Nasser', 'Estonia', 'Tajikistan']
# New Topics: ['Wayback_Machine', 'Comcast', 'Packet_switching']
# Assigned to: ['BBC_Television', 'Internet_service_provider', 'BeiDou_Navigation_Satellite_System', 'Communications_in_Somalia', 'General_Electric', 'Copyright_infringement', 'Royal_Dutch_Shell', 'Intellectual_property', 'CBC_Television', 'IBM', 'YouTube']
# New Topics: ['Canadian_Armed_Forces', 'Warsaw_Pact', 'Federal_Bureau_of_Investigation', 'Anti-aircraft_warfare', 'Central_Intelligence_Agency']
# Assigned to: ['Space_Race', 'Ministry_of_Defence_(United_Kingdom)', 'Aircraft_carrier', 'Federal_Aviation_Administration', 'Military_history_of_the_United_States', 'United_States_Army', 'Korean_War', 'Molotov%E2%80%93Ribbentrop_Pact', 'War_on_Terror', 'Elevator', 'The_Blitz', 'Pacific_War', 'Airport', 'United_States_Air_Force', 'Dwight_D._Eisenhower']
# New Topics: ['Cardinal_(Catholicism)', 'Heresy', 'Mary_(mother_of_Jesus)', 'Athanasius_of_Alexandria', 'Freemasonry', 'Protestantism']
# Assigned to: ['Canon_law', 'Presbyterianism', 'Pope_Paul_VI', 'Baptists', 'Dominican_Order', 'Pope_John_XXIII', 'Jehovah%27s_Witnesses']
# New Topics: ['Human_Development_Index', 'European_Central_Bank', 'Endangered_Species_Act', 'Egypt', 'Black_Death', 'Intergovernmental_Panel_on_Climate_Change']
# Assigned to: ['Republic_of_the_Congo', 'United_Nations_Population_Fund', 'Political_corruption', 'Guinea-Bissau', 'Somalis', 'Eritrea', 'Bill_%26_Melinda_Gates_Foundation', 'Mali', 'Nonprofit_organization', 'Nigeria', 'Child_labour', 'Central_African_Republic', 'Liberia', 'Swaziland', 'Namibia', 'Police', 'Genocide']
# New Topics: ['Materialism', 'Age_of_Enlightenment', 'On_the_Origin_of_Species', 'God', 'Karl_Popper', 'Muslim_world']
# Assigned to: ['Buddhism', 'Political_philosophy', 'Literature', 'Avicenna', 'History_of_science', 'Textual_criticism', 'Hindu_philosophy', 'Culture', 'Friedrich_Hayek', 'Empiricism', 'Idealism', 'Quran', 'Alfred_North_Whitehead', 'Humanism']
# New Topics: ['Pub', 'Southampton', 'Department_store', 'Oklahoma', 'Richmond,_Virginia', 'Southern_California', 'Fresno,_California', 'Jacksonville,_Florida']
# Assigned to: ['New_York_City', 'Plymouth', 'Oklahoma_City', 'Boston', 'National_Archives_and_Records_Administration', 'List_of_numbered_streets_in_Manhattan', 'Atlantic_City,_New_Jersey', 'Houston', 'Lancashire', 'Melbourne', 'Seattle', 'Somerset', 'Ann_Arbor,_Michigan', 'Raleigh,_North_Carolina', 'New_Haven,_Connecticut', 'Cork_(city)', 'Detroit', 'London', 'St._John%27s,_Newfoundland_and_Labrador', 'Miami', 'Philadelphia', 'Charleston,_South_Carolina', 'Santa_Monica,_California', 'Tucson,_Arizona', 'San_Diego', 'The_Bronx']
# New Topics: ['Catalan_language', 'Dialect', 'Sanskrit', 'Chinese_characters']
# Assigned to: ['Iranian_languages', 'Comics', 'Aspirated_consonant', 'Estonian_language', 'Slavs', 'Phonology', 'Letter_case', 'Old_English', 'Dutch_language', 'Hokkien', 'Unicode', 'Serbo-Croatian', 'Czech_language', 'Translation', 'Russian_language']
# New Topics: ['Paper', 'Alloy', 'Electric_motor', 'Capacitor', 'Zinc', 'Transistor', 'Steam_engine']
# Assigned to: ['Solar_energy', 'Lighting', 'Hydrogen', 'Wood', 'Copper', 'Beer', 'Infrared', 'Uranium', 'Asphalt', 'Incandescent_light_bulb', 'Glass', 'Renewable_energy_commercialization', 'Railway_electrification_system', 'Printed_circuit_board', 'Light-emitting_diode']
# New Topics: ['Adult_contemporary_music', 'Hard_rock', 'Marvel_Comics', 'Sky_(United_Kingdom)']
# Assigned to: ['Beyoncé', 'Spectre_(2015_film)', 'Kanye_West', 'American_Idol', 'Sony_Music_Entertainment', 'Universal_Studios', 'House_music', 'Queen_(band)', 'Madonna_(entertainer)', 'Turner_Classic_Movies', 'Steven_Spielberg']
# New Topics: ['Nanjing', 'Tibet']
# Assigned to: ['Zhejiang', 'New_Delhi', 'Himachal_Pradesh', 'Umayyad_Caliphate', 'Southeast_Asia', 'Sichuan', 'History_of_India', 'Rajasthan', 'Hyderabad', 'Punjab,_Pakistan', 'Kathmandu']
# New Topics: ['The_Times', 'Political_party', 'Scottish_Parliament']
# Assigned to: ['Arnold_Schwarzenegger', 'The_Sun_(United_Kingdom)', 'Labour_Party_(UK)', 'United_States_presidential_election,_2004', 'Liberal_Party_of_Australia', 'John_Kerry', 'Party_leaders_of_the_United_States_House_of_Representatives']
# New Topics: ['Immunology', 'Biodiversity', 'Poultry', 'Nutrition', 'Tuberculosis', 'Ctenophora', 'Immune_system']
# Assigned to: ['Dog', 'Genome', 'Symbiosis', 'Gene', 'Bird_migration', 'Animal', 'Digestion', 'Mammal', 'Predation', 'Botany', 'Pesticide', 'Asthma', 'Annelid', 'Insect', 'Diarrhea', 'Flowering_plant', 'Bacteria', 'Antibiotics', 'Bird', 'Infection', 'Hunting']
# New Topics: ['Imamah_(Shia_doctrine)', 'Immaculate_Conception']
# Assigned to: ['Christian', 'Virgil', 'Orthodox_Judaism', 'Gregorian_calendar', 'Ashkenazi_Jews', 'Jews', 'Crucifixion_of_Jesus', 'Apollo', 'Sumer']
# New Topics: ['Grape']
# Assigned to: ['Green', 'Red']
# New Topics: ['United_States_dollar', 'North_Carolina', '51st_state']
# Assigned to: ['Florida', 'Tennessee', 'Spanish_language_in_the_United_States']
# New Topics: ['Everton_F.C.']
# Assigned to: ['Arena_Football_League', 'England_national_football_team', 'Gymnastics', 'FC_Barcelona', 'Arsenal_F.C.', 'Chicago_Cubs', 'Professional_wrestling', 'FA_Cup', 'Exhibition_game', 'Canadian_football', 'Premier_League', 'Association_football']
# New Topics: ['Great_Plains', 'Appalachian_Mountains', 'Neptune', 'Amazon_rainforest', 'Geology']
# Assigned to: ['Alps', 'Mesozoic', 'Antarctica', 'Cotton', 'Glacier', 'Sahara', 'Geography_of_the_United_States', 'Geological_history_of_Earth']
# New Topics: ['Order_of_the_British_Empire', 'Elizabeth_II', 'Huguenot', 'French_and_Indian_War']
# Assigned to: ['To_Kill_a_Mockingbird', 'Dutch_Republic', 'John,_King_of_England', 'Franco-Prussian_War', 'Queen_Victoria', 'Napoleon', 'Germans', 'Edmund_Burke', 'Crimean_War', 'Alsace', 'George_VI', 'States_of_Germany', 'East_Prussia', 'Seven_Years%27_War']
# New Topics: ['Capital_punishment_in_the_United_States', 'European_Union_law', 'Civil_disobedience']
# Assigned to: ['Prime_minister', 'Separation_of_powers_under_the_United_States_Constitution', 'Treaty', 'Law_of_the_United_States', 'Supreme_court', 'Rule_of_law', 'Royal_assent', 'Federalism', 'Separation_of_church_and_state_in_the_United_States']
# New Topics: ['Montevideo', 'Utrecht', 'Rhine', 'Warsaw']
# Assigned to: ['Bern', 'Chihuahua_(state)', 'Hanover', 'Valencia', 'Mexico_City', 'Thuringia', 'Switzerland', 'Carnival', 'Galicia_(Spain)', 'Strasbourg', 'Paris', 'Palermo', 'Bras%C3%ADlia', 'Portugal']
# New Topics: ['Clothing']
# Assigned to: ['Black_people', 'Race_and_ethnicity_in_the_United_States_Census', 'Multiracial_American', 'Affirmative_action_in_the_United_States', 'Race_(human_categorization)', 'Neolithic', 'Indigenous_peoples_of_the_Americas']
# New Topics: ['Bermuda', 'Victoria_(Australia)']
# Assigned to: ['Saint_Helena', 'Tristan_da_Cunha', 'Marshall_Islands', 'Norfolk_Island', 'Samoa', 'Alaska', 'Guam', 'British_Isles', 'Tuvalu', 'Saint_Barth%C3%A9lemy', 'Montana']
# New Topics: ['Heian_period', 'Han_dynasty', 'Kievan_Rus%27', 'Normans', 'Yuan_dynasty']
# Assigned to: ['Sino-Tibetan_relations_during_the_Ming_dynasty', 'East_India_Company', 'British_Empire', 'Samurai', 'Modern_history', 'Great_power', 'Qing_dynasty']
# New Topics: ['Group_(mathematics)', 'Planck_constant', 'Richard_Feynman', 'Computational_complexity_theory', 'Prime_number', 'Force']
# Assigned to: ['Pitch_(music)', 'Time', 'John_von_Neumann', 'Energy', 'Philosophy_of_space_and_time', 'Vacuum', 'Matter']
# New Topics: ['Post-punk']
# Assigned to: ['Frédéric_Chopin', 'Classical_music', 'A_cappella', 'Mandolin']
# New Topics: ['Washington_University_in_St._Louis', 'Harvard_University', 'University_of_Chicago']
# Assigned to: ['Alexander_Graham_Bell', 'University_of_Kansas', 'Imperial_College_London', 'Brigham_Young_University', 'Yale_University', 'Eton_College', 'Northwestern_University', 'University_of_Notre_Dame']
# New Topics: ['Armenia']
# Assigned to: ['Near_East', 'Cyprus', 'Iran', 'Economy_of_Greece', 'Armenians']
# New Topics: ['Oxygen']
# Assigned to: ['Daylight_saving_time', 'Circadian_rhythm']
# New Topics: ['Pharmacy', 'Private_school']
# Assigned to: ['Comprehensive_school', 'Institute_of_technology', 'Madrasa', 'Education', 'University']
# New Topics: ['Construction']
# Assigned to: ['Westminster_Abbey', 'Buckingham_Palace', 'Gothic_architecture', 'Georgian_architecture', 'Mosaic']
# New Topics: ['Economic_inequality']
# Assigned to: ['Pharmaceutical_industry', 'Financial_crisis_of_2007%E2%80%9308']
# New Topics: ['Imperialism']
# Assigned to: ['Southern_Europe', 'Szlachta', 'Middle_Ages', 'Hellenistic_period', 'Greece', 'Late_Middle_Ages', 'Ottoman_Empire', 'Greeks', 'Roman_Republic', 'Religion_in_ancient_Rome']

# %% [markdown]
# ### Merge Mappings

# %%
merge_map = {k:v + new_map.get(k) for k,v in train_data_map.items() if (new_map.get(k))}
left_over = {k:v for k,v in new_map.items() if k not in train_data_map.keys()}
merge_map
# Out:
# {0: ['Beyoncé',
#   'Spectre_(2015_film)',
#   'Kanye_West',
#   'American_Idol',
#   'Sony_Music_Entertainment',
#   'Universal_Studios',
#   'House_music',
#   'Queen_(band)',
#   'Madonna_(entertainer)',
#   'Turner_Classic_Movies',
#   'Steven_Spielberg',
#   'Adult_contemporary_music',
#   'Hard_rock',
#   'Marvel_Comics',
#   'Sky_(United_Kingdom)'],
#  32: ['Frédéric_Chopin',
#   'Classical_music',
#   'A_cappella',
#   'Mandolin',
#   'Post-punk'],
#  30: ['Sino-Tibetan_relations_during_the_Ming_dynasty',
#   'East_India_Company',
#   'British_Empire',
#   'Samurai',
#   'Modern_history',
#   'Great_power',
#   'Qing_dynasty',
#   'Heian_period',
#   'Han_dynasty',
#   'Kievan_Rus%27',
#   'Normans',
#   'Yuan_dynasty'],
#  3: ['The_Legend_of_Zelda:_Twilight_Princess',
#   'High-definition_television',
#   'Computer',
#   'MP3',
#   'Computer_security',
#   'Videoconferencing',
#   'Xbox_360',
#   'ASCII',
#   'Macintosh',
#   'Dell',
#   'Nintendo_Entertainment_System',
#   'Film_speed',
#   'Data_compression',
#   'Digimon',
#   'Gramophone_record',
#   'USB',
#   'PlayStation_3',
#   'LaserDisc',
#   'Software_testing',
#   'Compact_disc',
#   'Database',
#   'Windows_8',
#   'Super_Nintendo_Entertainment_System',
#   'IPod',
#   'Web_browser',
#   'Antenna_(radio)'],
#  4: ['New_York_City',
#   'Plymouth',
#   'Oklahoma_City',
#   'Boston',
#   'National_Archives_and_Records_Administration',
#   'List_of_numbered_streets_in_Manhattan',
#   'Atlantic_City,_New_Jersey',
#   'Houston',
#   'Lancashire',
#   'Melbourne',
#   'Seattle',
#   'Somerset',
#   'Ann_Arbor,_Michigan',
#   'Raleigh,_North_Carolina',
#   'New_Haven,_Connecticut',
#   'Cork_(city)',
#   'Detroit',
#   'London',
#   'St._John%27s,_Newfoundland_and_Labrador',
#   'Miami',
#   'Philadelphia',
#   'Charleston,_South_Carolina',
#   'Santa_Monica,_California',
#   'Tucson,_Arizona',
#   'San_Diego',
#   'The_Bronx',
#   'Pub',
#   'Southampton',
#   'Department_store',
#   'Oklahoma',
#   'Richmond,_Virginia',
#   'Southern_California',
#   'Fresno,_California',
#   'Jacksonville,_Florida'],
#  26: ['To_Kill_a_Mockingbird',
#   'Dutch_Republic',
#   'John,_King_of_England',
#   'Franco-Prussian_War',
#   'Queen_Victoria',
#   'Napoleon',
#   'Germans',
#   'Edmund_Burke',
#   'Crimean_War',
#   'Alsace',
#   'George_VI',
#   'States_of_Germany',
#   'East_Prussia',
#   'Seven_Years%27_War',
#   'Order_of_the_British_Empire',
#   'Elizabeth_II',
#   'Huguenot',
#   'French_and_Indian_War'],
#  6: ['Solar_energy',
#   'Lighting',
#   'Hydrogen',
#   'Wood',
#   'Copper',
#   'Beer',
#   'Infrared',
#   'Uranium',
#   'Asphalt',
#   'Incandescent_light_bulb',
#   'Glass',
#   'Renewable_energy_commercialization',
#   'Railway_electrification_system',
#   'Printed_circuit_board',
#   'Light-emitting_diode',
#   'Paper',
#   'Alloy',
#   'Electric_motor',
#   'Capacitor',
#   'Zinc',
#   'Transistor',
#   'Steam_engine'],
#  7: ['Buddhism',
#   'Political_philosophy',
#   'Literature',
#   'Avicenna',
#   'History_of_science',
#   'Textual_criticism',
#   'Hindu_philosophy',
#   'Culture',
#   'Friedrich_Hayek',
#   'Empiricism',
#   'Idealism',
#   'Quran',
#   'Alfred_North_Whitehead',
#   'Humanism',
#   'Materialism',
#   'Age_of_Enlightenment',
#   'On_the_Origin_of_Species',
#   'God',
#   'Karl_Popper',
#   'Muslim_world'],
#  8: ['Dog',
#   'Genome',
#   'Symbiosis',
#   'Gene',
#   'Bird_migration',
#   'Animal',
#   'Digestion',
#   'Mammal',
#   'Predation',
#   'Botany',
#   'Pesticide',
#   'Asthma',
#   'Annelid',
#   'Insect',
#   'Diarrhea',
#   'Flowering_plant',
#   'Bacteria',
#   'Antibiotics',
#   'Bird',
#   'Infection',
#   'Hunting',
#   'Immunology',
#   'Biodiversity',
#   'Poultry',
#   'Nutrition',
#   'Tuberculosis',
#   'Ctenophora',
#   'Immune_system'],
#  2: ['2008_Summer_Olympics_torch_relay',
#   'Russian_Soviet_Federative_Socialist_Republic',
#   'Josip_Broz_Tito',
#   'Myanmar',
#   'Dissolution_of_the_Soviet_Union',
#   'Gamal_Abdel_Nasser',
#   'Estonia',
#   'Tajikistan',
#   '2008_Sichuan_earthquake',
#   'Muammar_Gaddafi',
#   '1973_oil_crisis',
#   'Islamism'],
#  9: ['Comprehensive_school',
#   'Institute_of_technology',
#   'Madrasa',
#   'Education',
#   'University',
#   'Pharmacy',
#   'Private_school'],
#  10: ['Republic_of_the_Congo',
#   'United_Nations_Population_Fund',
#   'Political_corruption',
#   'Guinea-Bissau',
#   'Somalis',
#   'Eritrea',
#   'Bill_%26_Melinda_Gates_Foundation',
#   'Mali',
#   'Nonprofit_organization',
#   'Nigeria',
#   'Child_labour',
#   'Central_African_Republic',
#   'Liberia',
#   'Swaziland',
#   'Namibia',
#   'Police',
#   'Genocide',
#   'Human_Development_Index',
#   'European_Central_Bank',
#   'Endangered_Species_Act',
#   'Egypt',
#   'Black_Death',
#   'Intergovernmental_Panel_on_Climate_Change'],
#  5: ['Prime_minister',
#   'Separation_of_powers_under_the_United_States_Constitution',
#   'Treaty',
#   'Law_of_the_United_States',
#   'Supreme_court',
#   'Rule_of_law',
#   'Royal_assent',
#   'Federalism',
#   'Separation_of_church_and_state_in_the_United_States',
#   'Capital_punishment_in_the_United_States',
#   'European_Union_law',
#   'Civil_disobedience'],
#  12: ['Iranian_languages',
#   'Comics',
#   'Aspirated_consonant',
#   'Estonian_language',
#   'Slavs',
#   'Phonology',
#   'Letter_case',
#   'Old_English',
#   'Dutch_language',
#   'Hokkien',
#   'Unicode',
#   'Serbo-Croatian',
#   'Czech_language',
#   'Translation',
#   'Russian_language',
#   'Catalan_language',
#   'Dialect',
#   'Sanskrit',
#   'Chinese_characters'],
#  11: ['Southern_Europe',
#   'Szlachta',
#   'Middle_Ages',
#   'Hellenistic_period',
#   'Greece',
#   'Late_Middle_Ages',
#   'Ottoman_Empire',
#   'Greeks',
#   'Roman_Republic',
#   'Religion_in_ancient_Rome',
#   'Imperialism'],
#  17: ['BBC_Television',
#   'Internet_service_provider',
#   'BeiDou_Navigation_Satellite_System',
#   'Communications_in_Somalia',
#   'General_Electric',
#   'Copyright_infringement',
#   'Royal_Dutch_Shell',
#   'Intellectual_property',
#   'CBC_Television',
#   'IBM',
#   'YouTube',
#   'Wayback_Machine',
#   'Comcast',
#   'Packet_switching'],
#  31: ['Arnold_Schwarzenegger',
#   'The_Sun_(United_Kingdom)',
#   'Labour_Party_(UK)',
#   'United_States_presidential_election,_2004',
#   'Liberal_Party_of_Australia',
#   'John_Kerry',
#   'Party_leaders_of_the_United_States_House_of_Representatives',
#   'The_Times',
#   'Political_party',
#   'Scottish_Parliament'],
#  14: ['Christian',
#   'Virgil',
#   'Orthodox_Judaism',
#   'Gregorian_calendar',
#   'Ashkenazi_Jews',
#   'Jews',
#   'Crucifixion_of_Jesus',
#   'Apollo',
#   'Sumer',
#   'Imamah_(Shia_doctrine)',
#   'Immaculate_Conception'],
#  15: ['Alexander_Graham_Bell',
#   'University_of_Kansas',
#   'Imperial_College_London',
#   'Brigham_Young_University',
#   'Yale_University',
#   'Eton_College',
#   'Northwestern_University',
#   'University_of_Notre_Dame',
#   'Washington_University_in_St._Louis',
#   'Harvard_University',
#   'University_of_Chicago'],
#  16: ['Saint_Helena',
#   'Tristan_da_Cunha',
#   'Marshall_Islands',
#   'Norfolk_Island',
#   'Samoa',
#   'Alaska',
#   'Guam',
#   'British_Isles',
#   'Tuvalu',
#   'Saint_Barth%C3%A9lemy',
#   'Montana',
#   'Bermuda',
#   'Victoria_(Australia)'],
#  13: ['Space_Race',
#   'Ministry_of_Defence_(United_Kingdom)',
#   'Aircraft_carrier',
#   'Federal_Aviation_Administration',
#   'Military_history_of_the_United_States',
#   'United_States_Army',
#   'Korean_War',
#   'Molotov%E2%80%93Ribbentrop_Pact',
#   'War_on_Terror',
#   'Elevator',
#   'The_Blitz',
#   'Pacific_War',
#   'Airport',
#   'United_States_Air_Force',
#   'Dwight_D._Eisenhower',
#   'Canadian_Armed_Forces',
#   'Warsaw_Pact',
#   'Federal_Bureau_of_Investigation',
#   'Anti-aircraft_warfare',
#   'Central_Intelligence_Agency'],
#  18: ['Canon_law',
#   'Presbyterianism',
#   'Pope_Paul_VI',
#   'Baptists',
#   'Dominican_Order',
#   'Pope_John_XXIII',
#   'Jehovah%27s_Witnesses',
#   'Cardinal_(Catholicism)',
#   'Heresy',
#   'Mary_(mother_of_Jesus)',
#   'Athanasius_of_Alexandria',
#   'Freemasonry',
#   'Protestantism'],
#  19: ['Daylight_saving_time', 'Circadian_rhythm', 'Oxygen'],
#  20: ['Arena_Football_League',
#   'England_national_football_team',
#   'Gymnastics',
#   'FC_Barcelona',
#   'Arsenal_F.C.',
#   'Chicago_Cubs',
#   'Professional_wrestling',
#   'FA_Cup',
#   'Exhibition_game',
#   'Canadian_football',
#   'Premier_League',
#   'Association_football',
#   'Everton_F.C.'],
#  21: ['Bern',
#   'Chihuahua_(state)',
#   'Hanover',
#   'Valencia',
#   'Mexico_City',
#   'Thuringia',
#   'Switzerland',
#   'Carnival',
#   'Galicia_(Spain)',
#   'Strasbourg',
#   'Paris',
#   'Palermo',
#   'Bras%C3%ADlia',
#   'Portugal',
#   'Montevideo',
#   'Utrecht',
#   'Rhine',
#   'Warsaw'],
#  29: ['Westminster_Abbey',
#   'Buckingham_Palace',
#   'Gothic_architecture',
#   'Georgian_architecture',
#   'Mosaic',
#   'Construction'],
#  22: ['Alps',
#   'Mesozoic',
#   'Antarctica',
#   'Cotton',
#   'Glacier',
#   'Sahara',
#   'Geography_of_the_United_States',
#   'Geological_history_of_Earth',
#   'Great_Plains',
#   'Appalachian_Mountains',
#   'Neptune',
#   'Amazon_rainforest',
#   'Geology'],
#  36: ['Near_East',
#   'Cyprus',
#   'Iran',
#   'Economy_of_Greece',
#   'Armenians',
#   'Armenia'],
#  24: ['Zhejiang',
#   'New_Delhi',
#   'Himachal_Pradesh',
#   'Umayyad_Caliphate',
#   'Southeast_Asia',
#   'Sichuan',
#   'History_of_India',
#   'Rajasthan',
#   'Hyderabad',
#   'Punjab,_Pakistan',
#   'Kathmandu',
#   'Nanjing',
#   'Tibet'],
#  25: ['Black_people',
#   'Race_and_ethnicity_in_the_United_States_Census',
#   'Multiracial_American',
#   'Affirmative_action_in_the_United_States',
#   'Race_(human_categorization)',
#   'Neolithic',
#   'Indigenous_peoples_of_the_Americas',
#   'Clothing'],
#  33: ['Pitch_(music)',
#   'Time',
#   'John_von_Neumann',
#   'Energy',
#   'Philosophy_of_space_and_time',
#   'Vacuum',
#   'Matter',
#   'Group_(mathematics)',
#   'Planck_constant',
#   'Richard_Feynman',
#   'Computational_complexity_theory',
#   'Prime_number',
#   'Force'],
#  27: ['Pharmaceutical_industry',
#   'Financial_crisis_of_2007%E2%80%9308',
#   'Economic_inequality'],
#  35: ['Florida',
#   'Tennessee',
#   'Spanish_language_in_the_United_States',
#   'United_States_dollar',
#   'North_Carolina',
#   '51st_state'],
#  34: ['Green', 'Red', 'Grape']}

# %%
left_over
# Out:
# {}

# %% [markdown]
# ## Comparing Merge Map with a Combined Map to check if we aren't forcing themes into clusters

# %%
paragraphs_c = pd.concat((paragraphs1,paragraphs2))
uniq_theme_list_c = uniq_theme_list1 + uniq_theme_list2
combined_paras = para_list1 + para_list2
para_embeddings_c = generate_embeddings(embedding_model, combined_paras)
# Out:
# Generating the document embeddings...

# %%
topic_model_c = BERTopic(
                  low_memory = True,
                  umap_model = umap_model,
                  hdbscan_model = brc_model,
                  embedding_model = embedding_model,
                  vectorizer_model = vectorizer_model, 
                  calculate_probabilities = True, 
                  verbose = True, 
                  nr_topics = int(0.3*len(uniq_theme_list_c))
                )

# %%
fit_bertopic_model(topic_model_c, combined_paras,para_embeddings_c)
topics, scores = perform_cluster_prediction(topic_model_c, combined_paras, para_embeddings_c)
theme_to_cluster_mapping = generate_theme_to_cluster_mapping(paragraphs_c, topics)
cid_to_themes_mapping = (get_cid_to_list_topics(theme_to_cluster_mapping))
avg_themes_per_cluster = get_avg_themes_per_cluster(topic_model_c)
topic_info = topic_model_c.get_topic_info()
unclustered = topic_info[topic_info['Topic']==-1]['Count']
if unclustered.empty:
  unclustered = 0
  num_clusters = len(topic_info['Topic'])
else:
  unclustered = int(unclustered)
  num_clusters = len(topic_info['Topic'])-1
print('--------------------------------------------------------------------------------------------------------------------------------------------')
print(f"Merged Dataset Results:")
print(f"#Themes unclustered = {unclustered}\nAvg. #Themes / cluster = {avg_themes_per_cluster}\n# clusters = {num_clusters}")
# Out:
# Fitting the model using the paras & their embeddings
# 2023-02-03 16:59:35,146 - BERTopic - Reduced dimensionality
# 2023-02-03 16:59:35,166 - BERTopic - Clustered reduced embeddings
# 2023-02-03 16:59:39,935 - BERTopic - Reduced number of topics from 43 to 43
# 2023-02-03 16:59:42,349 - BERTopic - Reduced dimensionality
# 2023-02-03 16:59:42,352 - BERTopic - Predicted clusters
# --------------------------------------------------------------------------------------------------------------------------------------------
# Merged Dataset Results:
# #Themes unclustered = 0
# Avg. #Themes / cluster = 11.093023255813954
# # clusters = 43

# %%
combined_map = cid_to_themes_mapping

# %%
combined_map
# Out:
# {0: ['IPod',
#   'Wayback_Machine',
#   'Web_browser',
#   'Comcast',
#   'Sky_(United_Kingdom)',
#   'Packet_switching',
#   'The_Legend_of_Zelda:_Twilight_Princess',
#   'BBC_Television',
#   'Internet_service_provider',
#   'BeiDou_Navigation_Satellite_System',
#   'Communications_in_Somalia',
#   'High-definition_television',
#   'Computer',
#   'MP3',
#   'Computer_security',
#   'Videoconferencing',
#   'Xbox_360',
#   'ASCII',
#   'Macintosh',
#   'Dell',
#   'Nintendo_Entertainment_System',
#   'Copyright_infringement',
#   'Film_speed',
#   'Intellectual_property',
#   'Data_compression',
#   'Digimon',
#   'Gramophone_record',
#   'USB',
#   'PlayStation_3',
#   'LaserDisc',
#   'Software_testing',
#   'CBC_Television',
#   'IBM',
#   'Compact_disc',
#   'Database',
#   'Windows_8',
#   'Super_Nintendo_Entertainment_System',
#   'YouTube'],
#  1: ['2008_Sichuan_earthquake',
#   'Nanjing',
#   'Heian_period',
#   'Tibet',
#   'Han_dynasty',
#   'Yuan_dynasty',
#   'Sino-Tibetan_relations_during_the_Ming_dynasty',
#   '2008_Summer_Olympics_torch_relay',
#   'Zhejiang',
#   'Umayyad_Caliphate',
#   'Sichuan',
#   'History_of_India',
#   'Samurai',
#   'Qing_dynasty'],
#  2: ['Canadian_Armed_Forces',
#   'Anti-aircraft_warfare',
#   'Central_Intelligence_Agency',
#   'Space_Race',
#   'Ministry_of_Defence_(United_Kingdom)',
#   'Aircraft_carrier',
#   'Federal_Aviation_Administration',
#   'Military_history_of_the_United_States',
#   'United_States_Army',
#   'Korean_War',
#   'War_on_Terror',
#   'Elevator',
#   'The_Blitz',
#   'Pacific_War',
#   'Airport',
#   'United_States_Air_Force',
#   'Dwight_D._Eisenhower'],
#  3: ['Cardinal_(Catholicism)',
#   'Heresy',
#   'Mary_(mother_of_Jesus)',
#   'Athanasius_of_Alexandria',
#   'Immaculate_Conception',
#   'Protestantism',
#   'Christian',
#   'Canon_law',
#   'Gregorian_calendar',
#   'Presbyterianism',
#   'Pope_Paul_VI',
#   'Baptists',
#   'Crucifixion_of_Jesus',
#   'Dominican_Order',
#   'Pope_John_XXIII',
#   'Jehovah%27s_Witnesses'],
#  4: ['Human_Development_Index',
#   'Muammar_Gaddafi',
#   'Egypt',
#   '1973_oil_crisis',
#   'Economic_inequality',
#   'Republic_of_the_Congo',
#   'United_Nations_Population_Fund',
#   'Political_corruption',
#   'Guinea-Bissau',
#   'Somalis',
#   'Eritrea',
#   'Bill_%26_Melinda_Gates_Foundation',
#   'Mali',
#   'Nonprofit_organization',
#   'Nigeria',
#   'Child_labour',
#   'Central_African_Republic',
#   'Liberia',
#   'Swaziland',
#   'Namibia',
#   'Economy_of_Greece',
#   'Financial_crisis_of_2007%E2%80%9308',
#   'Genocide'],
#  31: ['Warsaw_Pact',
#   'Islamism',
#   'Russian_Soviet_Federative_Socialist_Republic',
#   'Josip_Broz_Tito',
#   'Molotov%E2%80%93Ribbentrop_Pact',
#   'Dissolution_of_the_Soviet_Union',
#   'Gamal_Abdel_Nasser',
#   'Estonia'],
#  5: ['Materialism',
#   'Age_of_Enlightenment',
#   'On_the_Origin_of_Species',
#   'Group_(mathematics)',
#   'God',
#   'Karl_Popper',
#   'Computational_complexity_theory',
#   'Prime_number',
#   'Buddhism',
#   'Political_philosophy',
#   'History_of_science',
#   'Hindu_philosophy',
#   'Culture',
#   'John_von_Neumann',
#   'Friedrich_Hayek',
#   'Empiricism',
#   'Idealism',
#   'Alfred_North_Whitehead',
#   'Humanism'],
#  6: ['Pub',
#   'Southampton',
#   'Plymouth',
#   'Beer',
#   'Lancashire',
#   'Somerset',
#   'Cork_(city)',
#   'London',
#   'St._John%27s,_Newfoundland_and_Labrador'],
#  7: ['Catalan_language',
#   'Dialect',
#   'Sanskrit',
#   'Chinese_characters',
#   'Iranian_languages',
#   'Aspirated_consonant',
#   'Estonian_language',
#   'Slavs',
#   'Phonology',
#   'Letter_case',
#   'Old_English',
#   'Dutch_language',
#   'Hokkien',
#   'Unicode',
#   'Serbo-Croatian',
#   'Czech_language',
#   'Translation',
#   'Russian_language'],
#  8: ['Paper',
#   'Alloy',
#   'Electric_motor',
#   'Capacitor',
#   'Zinc',
#   'Transistor',
#   'Antenna_(radio)',
#   'Steam_engine',
#   'Oxygen',
#   'Solar_energy',
#   'Lighting',
#   'Hydrogen',
#   'Wood',
#   'Pitch_(music)',
#   'Copper',
#   'Infrared',
#   'Uranium',
#   'Asphalt',
#   'Incandescent_light_bulb',
#   'Glass',
#   'Renewable_energy_commercialization',
#   'Railway_electrification_system',
#   'Printed_circuit_board',
#   'Light-emitting_diode'],
#  9: ['Adult_contemporary_music',
#   'Hard_rock',
#   'Marvel_Comics',
#   'Post-punk',
#   'Beyoncé',
#   'Frédéric_Chopin',
#   'Spectre_(2015_film)',
#   'Kanye_West',
#   'American_Idol',
#   'Sony_Music_Entertainment',
#   'Comics',
#   'Universal_Studios',
#   'Classical_music',
#   'House_music',
#   'Queen_(band)',
#   'Madonna_(entertainer)',
#   'Turner_Classic_Movies',
#   'A_cappella',
#   'Mandolin',
#   'Steven_Spielberg'],
#  10: ['The_Times', 'United_States_dollar', 'European_Central_Bank'],
#  11: ['Immunology',
#   'Nutrition',
#   'Tuberculosis',
#   'Ctenophora',
#   'Immune_system',
#   'Genome',
#   'Symbiosis',
#   'Gene',
#   'Brain',
#   'Animal',
#   'Digestion',
#   'Mammal',
#   'Predation',
#   'Botany',
#   'Pesticide',
#   'Annelid',
#   'Insect',
#   'Diarrhea',
#   'Flowering_plant',
#   'Bacteria',
#   'Antibiotics',
#   'Bird',
#   'Infection'],
#  12: ['Imamah_(Shia_doctrine)',
#   'Muslim_world',
#   'Literature',
#   'Avicenna',
#   'Textual_criticism',
#   'Quran'],
#  39: ['Grape', 'Cotton', 'Green'],
#  14: ['Everton_F.C.',
#   'Arena_Football_League',
#   'England_national_football_team',
#   'Gymnastics',
#   'FC_Barcelona',
#   'Arsenal_F.C.',
#   'Chicago_Cubs',
#   'Professional_wrestling',
#   'FA_Cup',
#   'Exhibition_game',
#   'Canadian_football',
#   'Premier_League',
#   'Association_football'],
#  15: ['Great_Plains',
#   'Appalachian_Mountains',
#   'Alps',
#   'Alaska',
#   'Geography_of_the_United_States',
#   'Montana'],
#  13: ['Biodiversity',
#   'Poultry',
#   'Clothing',
#   'Endangered_Species_Act',
#   'Dog',
#   'Hunter-gatherer',
#   'Bird_migration',
#   'Hunting'],
#  16: ['Federal_Bureau_of_Investigation',
#   'Arnold_Schwarzenegger',
#   'The_Sun_(United_Kingdom)',
#   'John_Kerry',
#   'Police'],
#  17: ['Order_of_the_British_Empire',
#   'Elizabeth_II',
#   'Freemasonry',
#   'To_Kill_a_Mockingbird',
#   'Westminster_Abbey',
#   'Queen_Victoria',
#   'Buckingham_Palace',
#   'Edmund_Burke',
#   'George_VI'],
#  18: ['Capital_punishment_in_the_United_States',
#   'European_Union_law',
#   'Civil_disobedience',
#   'Prime_minister',
#   'Separation_of_powers_under_the_United_States_Constitution',
#   'Treaty',
#   'Law_of_the_United_States',
#   'Supreme_court',
#   'Rule_of_law',
#   'Royal_assent',
#   'Federalism',
#   'Separation_of_church_and_state_in_the_United_States'],
#  19: ['Montevideo',
#   'Utrecht',
#   'Warsaw',
#   'Bern',
#   'Chihuahua_(state)',
#   'Hanover',
#   'Valencia',
#   'Mexico_City',
#   'Thuringia',
#   'Switzerland',
#   'Carnival',
#   'Galicia_(Spain)',
#   'Strasbourg',
#   'Paris',
#   'Palermo',
#   'Red',
#   'Bras%C3%ADlia',
#   'Portugal'],
#  21: ['Department_store',
#   'North_Carolina',
#   'Oklahoma',
#   'Richmond,_Virginia',
#   'Southern_California',
#   'Victoria_(Australia)',
#   'Fresno,_California',
#   'Jacksonville,_Florida',
#   'New_York_City',
#   'Oklahoma_City',
#   'Boston',
#   'List_of_numbered_streets_in_Manhattan',
#   'Atlantic_City,_New_Jersey',
#   'Houston',
#   'Melbourne',
#   'Seattle',
#   'Florida',
#   'Ann_Arbor,_Michigan',
#   'Raleigh,_North_Carolina',
#   'New_Haven,_Connecticut',
#   'Detroit',
#   'Miami',
#   'Philadelphia',
#   'Tennessee',
#   'Charleston,_South_Carolina',
#   'Santa_Monica,_California',
#   'Tucson,_Arizona',
#   'San_Diego',
#   'The_Bronx'],
#  20: ['Bermuda',
#   '51st_state',
#   'Saint_Helena',
#   'Tristan_da_Cunha',
#   'Marshall_Islands',
#   'Norfolk_Island',
#   'Samoa',
#   'Guam',
#   'Spanish_language_in_the_United_States',
#   'British_Isles',
#   'Tuvalu',
#   'Saint_Barth%C3%A9lemy'],
#  40: ['Political_party',
#   'Scottish_Parliament',
#   'Labour_Party_(UK)',
#   'United_States_presidential_election,_2004',
#   'Liberal_Party_of_Australia',
#   'Party_leaders_of_the_United_States_House_of_Representatives'],
#  22: ['Planck_constant',
#   'Richard_Feynman',
#   'Force',
#   'Time',
#   'Energy',
#   'Philosophy_of_space_and_time',
#   'Vacuum',
#   'Matter'],
#  26: ['Neptune',
#   'Amazon_rainforest',
#   'Geology',
#   'Intergovernmental_Panel_on_Climate_Change',
#   'Mesozoic',
#   'Antarctica',
#   'Glacier',
#   'Sahara',
#   'Geological_history_of_Earth'],
#  23: ['Washington_University_in_St._Louis',
#   'Harvard_University',
#   'University_of_Chicago',
#   'Alexander_Graham_Bell',
#   'National_Archives_and_Records_Administration',
#   'University_of_Kansas',
#   'Imperial_College_London',
#   'Brigham_Young_University',
#   'Yale_University',
#   'Eton_College',
#   'Northwestern_University',
#   'University_of_Notre_Dame'],
#  24: ['Armenia',
#   'Kievan_Rus%27',
#   'Imperialism',
#   'Southern_Europe',
#   'Near_East',
#   'Greece',
#   'Ottoman_Empire',
#   'Cyprus',
#   'Modern_history',
#   'Armenians'],
#  25: ['Normans',
#   'Huguenot',
#   'Black_Death',
#   'French_and_Indian_War',
#   'Dutch_Republic',
#   'Szlachta',
#   'Middle_Ages',
#   'John,_King_of_England',
#   'Franco-Prussian_War',
#   'East_India_Company',
#   'Napoleon',
#   'Germans',
#   'British_Empire',
#   'Late_Middle_Ages',
#   'Crimean_War',
#   'Alsace',
#   'States_of_Germany',
#   'East_Prussia',
#   'Seven_Years%27_War',
#   'Great_power'],
#  27: ['Pharmacy'],
#  28: ['Construction',
#   'Architecture',
#   'Royal_Institute_of_British_Architects',
#   'Gothic_architecture',
#   'Cubism',
#   'Neoclassical_architecture',
#   'Georgian_architecture',
#   'Mosaic'],
#  29: ['Private_school',
#   'Comprehensive_school',
#   'Institute_of_technology',
#   'Madrasa',
#   'Education',
#   'University'],
#  30: ['Rhine'],
#  36: ['Daylight_saving_time',
#   'Circadian_rhythm',
#   'Pharmaceutical_industry',
#   'Asthma',
#   'Myocardial_infarction'],
#  37: ['Virgil',
#   'Hellenistic_period',
#   'Apollo',
#   'Greeks',
#   'Roman_Republic',
#   'Religion_in_ancient_Rome'],
#  33: ['Black_people',
#   'Race_and_ethnicity_in_the_United_States_Census',
#   'Multiracial_American',
#   'Affirmative_action_in_the_United_States',
#   'Race_(human_categorization)'],
#  41: ['New_Delhi',
#   'Himachal_Pradesh',
#   'Rajasthan',
#   'Hyderabad',
#   'Punjab,_Pakistan',
#   'Kathmandu'],
#  35: ['Identity_(social_science)',
#   'Communication',
#   'Emotion',
#   'Adolescence',
#   'Sexual_orientation',
#   'Memory',
#   'Pain',
#   'Anthropology'],
#  32: ['Orthodox_Judaism', 'Ashkenazi_Jews', 'Jews', 'Sumer'],
#  34: ['General_Electric', 'Royal_Dutch_Shell'],
#  38: ['Israel', 'Southeast_Asia', 'Myanmar', 'Iran', 'Tajikistan'],
#  42: ['Neolithic', 'Indigenous_peoples_of_the_Americas']}

# %%
topic_model_c.save('cluster_model', save_embedding_model=False)

# %%
topic_model_c.get_topic_info()
# Out:
#     Topic  Count                                          Name
# 0       0     38                 0_data_apple_software_windows
# 1       1     14                   1_chinese_china_dynasty_han
# 2       2     17                     2_air_aircraft_forces_war
# 3       3     16                      3_church_mary_pope_jesus
# 4       4     23             4_gaddafi_country_africa_children
# 5       5     19         5_theory_god_philosophy_enlightenment
# 6       6      9            6_london_southampton_beer_plymouth
# 7       7     18      7_language_languages_characters_dialects
# 8       8     24                   8_used_antenna_light_copper
# 9       9     20                    9_music_album_film_madonna
# 10     10      3                     10_dollar_times_coins_ecb
# 11     11     23                11_cells_species_bacteria_cell
# 12     12      6                          12_quran_al_ibn_text
# 13     13      8                   13_species_hunting_dogs_dog
# 14     14     13                   14_league_football_club_cup
# 15     15      6          15_alaska_mountains_montana_mountain
# 16     16      5            16_kerry_fbi_schwarzenegger_police
# 17     17      9                 17_burke_victoria_queen_lodge
# 18     18     12                     18_law_court_state_states
# 19     19     18                      19_city_paris_red_mexico
# 20     20     12              20_island_islands_bermuda_tuvalu
# 21     21     29                        21_city_new_state_area
# 22     22      8               22_energy_feynman_vacuum_matter
# 23     23     12             23_university_school_bell_college
# 24     24     10            24_ottoman_empire_armenian_armenia
# 25     25     20                 25_french_france_napoleon_war
# 26     26      9           26_neptune_ice_antarctica_antarctic
# 27     27      1    27_pharmacy_pharmacists_pharmacies_patient
# 28     28      8         28_architecture_mosaic_mosaics_cubism
# 29     29      6  29_schools_education_universities_university
# 30     30      1                    30_rhine_delta_river_flows
# 31     31      8                 31_nasser_soviet_tito_estonia
# 32     32      4             32_jews_jewish_ashkenazi_orthodox
# 33     33      5                  33_race_racial_black_african
# 34     34      2                       34_shell_ge_company_oil
# 35     35      8                35_sexual_pain_memory_identity
# 36     36      5                      36_dst_asthma_time_clock
# 37     37      6                        37_greek_rome_roman_bc
# 38     38      5                38_israel_iran_myanmar_israeli
# 39     39      3                  39_cotton_green_color_grapes
# 40     40      6           40_party_leader_parliament_minority
# 41     41      6            41_kathmandu_hyderabad_delhi_india
# 42     42      2        42_indigenous_peoples_neolithic_native
